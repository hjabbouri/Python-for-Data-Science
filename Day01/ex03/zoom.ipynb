# %%
from load_image import ft_load
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

img = ft_load('animal.jpeg')
# print(img)
arr = img[100:500, 450:850, 0:1]
pic = img[100:500, 450:850, 0]
print(f'New shape after slicing: {arr.shape} or {arr.shape[0:2]}')
print(arr)
plt.imshow(arr)

data = Image.fromarray(pic)
data.show()
data.save('zoom.jpeg')
# Out:
# The shape of image is: (768, 1024, 3)
# New shape after slicing: (400, 400, 1) or
# [[[167]
#   [180]
#   [194]
#   ...
#   [ 64]
#   [ 50]
#   [ 72]]
#
#  [[161]
#   [171]
#   [184]
#   ...
#   [ 77]
#   [ 77]
#   [ 88]]
#
#  [[163]
#   [170]
#   [178]
#   ...
#   [ 82]
#   [ 95]
#   [ 94]]
#
#  ...
#
#  [[105]
#   [112]
#   [122]
#   ...
#   [102]
#   [105]
#   [105]]
#
#  [[114]
#   [114]
#   [126]
#   ...
#   [103]
#   [104]
#   [104]]
#
#  [[115]
#   [116]
#   [119]
#   ...
#   [103]
#   [103]
#   [103]]]
